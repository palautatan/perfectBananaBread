# %% [markdown]
# # Libraries

# %%
# DATA SCIENCE
import pandas as pd
import numpy as np
from collections import Counter

# WEBSCRAPING
from bs4 import BeautifulSoup
import requests
import requests_cache

# OTHER
import os

# VISUALIZATION
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (18, 12)
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
bbtable = pd.read_csv("banana_bread_df.csv")

# %%
bbtable.head()
# Out:
#                                                  url  \
# 0  http://allrecipes.com/recipe/23082/janets-famo...
# 1  http://allrecipes.com/recipe/6765/4h-banana-br...
# 2  http://allrecipes.com/recipe/218541/caramel-ma...
# 3  http://allrecipes.com/recipe/219967/chef-johns...
# 4  http://allrecipes.com/recipe/7154/creamy-banan...
#
#                              title  made-it  reviews  longRating  ratingValue  \
# 0  Janet's Famous Banana Nut Bread      151      110    4.634921         4.63
# 1                  4H Banana Bread      340      881    4.671642         4.67
# 2   Caramel Macchiato Banana Bread      188       57    4.181818         4.18
# 3         Chef John's Banana Bread      981      381    4.694737         4.69
# 4              Creamy Banana Bread      342      869    4.664100         4.66
#
#    reviewCount                                             recipe  calories  \
# 0          110  ['3 cups white sugar', '3/4 cup butter, soften...     356.0
# 1          881  ['2 cups all-purpose flour', '1/2 teaspoon bak...     265.0
# 2           57  ['cooking spray', '2 cups all-purpose flour', ...     334.0
# 3          381  ['cooking spray', '2 cups all-purpose flour', ...     334.0
# 4          869  ['1/2 cup margarine, softened', '1 (8 ounce) p...     289.0
#
#    ratings    prep         cook        total
# 0    126.0  ['20']   ['1', '5']  ['1', '25']
# 1   1072.0  ['10']        ['1']  ['1', '10']
# 2     66.0  ['15']   ['1', '5']        ['2']
# 3    475.0  ['15']  ['1', '10']  ['1', '45']
# 4   1039.0  ['30']       ['45']  ['1', '15']

# %% [markdown]
# # Exploration

# %%
Counter(" ".join(bbtable["title"]).split(" ")).most_common()
# Out:
# [('Banana', 170),
#  ('Bread', 165),
#  ('Nut', 28),
#  ('Chocolate', 11),
#  ('Whole', 10),
#  ('and', 10),
#  ('Wheat', 8),
#  ('Muffins', 7),
#  ('Chip', 7),
#  ('Best', 6),
#  ('Butter', 6),
#  ('Cream', 5),
#  ('Quick', 5),
#  ('Delicious', 5),
#  ('Loaf', 5),
#  ('Sour', 4),
#  ('Fat', 4),
#  ('II', 4),
#  ('I', 4),
#  ('Sugar', 4),
#  ('Peanut', 4),
#  ('Blueberry', 4),
#  ('Oatmeal', 4),
#  ('Grain', 4),
#  ('Walnut', 4),
#  ('Raisin', 4),
#  ('with', 4),
#  ('Gluten-Free', 4),
#  ("Janet's", 3),
#  ('Caramel', 3),
#  ("Grandma's", 3),
#  ('Rich', 3),
#  ('The', 3),
#  ('Easy', 3),
#  ('Lower', 3),
#  ('Brown', 3),
#  ('Sweet', 3),
#  ('Free', 3),
#  ('Cranberry', 3),
#  ('Recipe', 3),
#  ('Paleo', 3),
#  ('Moist', 3),
#  ('Famous', 2),
#  ('Macchiato', 2),
#  ('Chef', 2),
#  ("John's", 2),
#  ('Raspberry', 2),
#  ('Homemade', 2),
#  ('Banana-Zucchini', 2),
#  ('Crumb', 2),
#  ('Ever', 2),
#  ('Pumpkin', 2),
#  ('for', 2),
#  ('Hawaiian', 2),
#  ('Favorite', 2),
#  ('Bran', 2),
#  ('a', 2),
#  ('Strawnana', 2),
#  ('Maple', 2),
#  ('Flaxseed', 2),
#  ('Healthier', 2),
#  ('Simple', 2),
#  ('Monkey', 2),
#  ('Strawberry', 2),
#  ('Ginger', 2),
#  ('Zucchini', 2),
#  ('Oat', 2),
#  ('Nutty', 2),
#  ('Cinnamon', 2),
#  ('Double', 2),
#  ('Yogurt', 2),
#  ('4H', 1),
#  ('Creamy', 1),
#  ('Extreme', 1),
#  ("'EBNB'", 1),
#  ("Cathy's", 1),
#  ("Sarah's", 1),
#  ('Almost', 1),
#  ('No', 1),
#  ("Janine's", 1),
#  ('Lighter', 1),
#  ("Joy's", 1),
#  ('-', 1),
#  ('Machines', 1),
#  ('Coconut', 1),
#  ("Mother's", 1),
#  ('Baked', 1),
#  ('in', 1),
#  ('Jar', 1),
#  ("Nanna's", 1),
#  ('III', 1),
#  ("Granny's", 1),
#  ('Spiced', 1),
#  ('Healthy', 1),
#  ('Gluten', 1),
#  ('Special', 1),
#  ('Date', 1),
#  ('Chai', 1),
#  ('Country', 1),
#  ('We', 1),
#  ('Be', 1),
#  ("Jammin'", 1),
#  ('Jamaican', 1),
#  ('Family', 1),
#  ('Browned', 1),
#  ('Bananas', 1),
#  ('Foster', 1),
#  ('Really', 1),
#  ("Bangin'", 1),
#  ('Molasses', 1),
#  ('Apple', 1),
#  ('Butterscotch', 1),
#  ("Napoleon's", 1),
#  ('Muffin', 1),
#  ('Cornbread', 1),
#  ('Low-Fat', 1),
#  ('Cranapana', 1),
#  ('Amish', 1),
#  ('Friendship', 1),
#  ("Angie's", 1),
#  ('To-Die-For', 1),
#  ("Mommy's", 1),
#  ("Bobra's", 1),
#  ('Greatest', 1),
#  ('Smoothie', 1),
#  ('Cardamom', 1),
#  ('Roasted', 1),
#  ('Pecan', 1),
#  ('Loaves', 1),
#  ("Oz's", 1),
#  ('Banana-Nut', 1),
#  ('ABM', 1),
#  ('Mrs.', 1),
#  ("Kurtz's", 1),
#  ('Salted', 1),
#  ('Oat-Streusel', 1),
#  ('Topping', 1),
#  ('Simply', 1),
#  ('Brazilian', 1),
#  ('Macadamia', 1),
#  ('Fig', 1),
#  ('from', 1),
#  ("Mott's®", 1),
#  ('Plum', 1),
#  ('Basic', 1),
#  ('Fruit', 1),
#  ("Dad's", 1),
#  ("Mom's", 1),
#  ('Carrot', 1),
#  ('Honey-Spice', 1),
#  ('Mix', 1),
#  ('Breakfast', 1),
#  ('Cake', 1),
#  ('Bates', 1),
#  ('Peach', 1),
#  ('Buttermilk', 1),
#  ('Choc', 1),
#  ('Cherry', 1),
#  ('Pineapple', 1),
#  ('', 1),
#  ('Whiskey', 1),
#  ('Bacon', 1),
#  ('Upside-Down', 1),
#  ('My', 1),
#  ("Aunt's", 1),
#  ('Sunflower', 1),
#  ('Bitter', 1),
#  ('Chocolate,', 1),
#  ('Lavender,', 1),
#  ('Tea', 1),
#  ('Powerhouse', 1),
#  ('Melted', 1),
#  ('Microwave', 1),
#  ('Tofu', 1),
#  ('Vegan', 1),
#  ('Oats', 1),
#  ('Cheese', 1),
#  ('Made', 1),
#  ('Very', 1),
#  ('Banana-y', 1),
#  ('Papaya', 1),
#  ('Twist', 1),
#  ('Black', 1),
#  ('Sesame', 1),
#  ('Lotus', 1),
#  ('Cookie', 1),
#  ('Organic', 1),
#  ('Tangy', 1),
#  ('Flax', 1),
#  ('Seed', 1),
#  ('Potato', 1),
#  ('Giraffe', 1),
#  ('Dark', 1),
#  ('Marbled', 1),
#  ('Greek', 1)]
